# %% [markdown]
# <a href="https://colab.research.google.com/github/Bibitpamungkas/praktikumML_314_321/blob/Praktikum/Copy_of_Modul_6_Praktikum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Tulis Program Anda Disini!
# Basic Imports
import numpy as np
import matplotlib.pyplot as plt
from glob import glob
from PIL import Image

# Imports untuk membangun CNN
from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, load_model

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (5.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.10.8)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.62.3)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/tmp/"

# %%
# jika anda ingin menggunakan kaggle API untuk mengunduh dataset gunakan
# kode berikut untuk membantu anda membuat config kaggle.json
# pastikan anda mendaftar akun kaggle terlebih dahulu
# kemudian menuju halaman my account dan buat token API anda

api_token = {"username":"bibitpamungkas","key":"0b4a500fd9a858ee152de296398002ab"}
import json
import zipfile
import os
with open('/tmp/kaggle.json', 'w') as file:
    json.dump(api_token, file)
# !chmod 600 /tmp/kaggle.json

# %%
# !kaggle datasets download -d jtiptj/chest-xray-pneumoniacovid19tuberculosis
# Out:
# Downloading chest-xray-pneumoniacovid19tuberculosis.zip to /content
# 100% 1.74G/1.74G [00:57<00:00, 19.8MB/s]
# 100% 1.74G/1.74G [00:57<00:00, 32.2MB/s]

# %%
# Ekstrak dataset

import os
import zipfile

os.makedirs('/tmp/chest-xray-pneumoniacovid19tuberculosis')

local_zip = '/content/chest-xray-pneumoniacovid19tuberculosis.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp/chest-xray-pneumoniacovid19tuberculosis')
zip_ref.close()

# %%
import os
base_dir = '/tmp/chest-xray-pneumoniacovid19tuberculosis'
train = os.path.join(base_dir,'train')
validation = os.path.join(base_dir,'val')
test = os.path.join(base_dir,'test')

c19_tr = os.path.join(train,'COVID19')
c19_va = os.path.join(validation,'COVID19')
c19_ts = os.path.join(test,'COVID19')

nr_tr = os.path.join(train,'NORMAL')
nr_va = os.path.join(validation,'NORMAL')
nr_ts = os.path.join(test,'NORMAL')

pn_tr = os.path.join(train,'PNEUMONIA')
pn_va = os.path.join(validation,'PNEUMONIA')
pn_ts = os.path.join(test,'PNEUMONIA')

tb_tr = os.path.join(train,'TURBERCULOSIS')
tb_va = os.path.join(validation,'TURBERCULOSIS')
tb_ts = os.path.join(test,'TURBERCULOSIS')

#file training dan validation
file_train_c19 = os.listdir(c19_tr)
file_validation_c19 = os.listdir(c19_va)
file_test_c19 = os.listdir(c19_ts)
file_train_nr = os.listdir(nr_tr)
file_validation_nr = os.listdir(nr_va)
file_test_nr = os.listdir(nr_ts)
file_train_pn = os.listdir(pn_tr)
file_validation_pn = os.listdir(pn_va)
file_test_pn = os.listdir(pn_ts)
file_train_tb = os.listdir(tb_tr)
file_validation_tb = os.listdir(tb_va)
file_test_tb = os.listdir(tb_ts)

#Print jumlah data training dan validation
print("Data COVID19 Train : " + str(len(file_train_c19)))
print("Data COVID19 Validation : " + str(len(file_validation_c19)))
print("Data COVID19 Test : " + str(len(file_test_c19)))
print("Data NORMAL Train : " + str(len(file_train_nr)))
print("Data NORMAL Validation : " + str(len(file_validation_nr)))
print("Data NORMAL Test : " + str(len(file_test_nr)))
print("Data PNEUMONIA Train : " + str(len(file_train_pn)))
print("Data PNEUMONIA Validation : " + str(len(file_validation_pn)))
print("Data PNEUMONIA Test : " + str(len(file_test_pn)))
print("Data TURBERCULOSIS Train : " + str(len(file_train_tb)))
print("Data TURBERCULOSIS Validation : " + str(len(file_validation_tb)))
print("Data TURBERCULOSIS Test : " + str(len(file_test_tb)))
# Out:
# Data COVID19 Train : 460
# Data COVID19 Validation : 10
# Data COVID19 Test : 106
# Data NORMAL Train : 1341
# Data NORMAL Validation : 8
# Data NORMAL Test : 234
# Data PNEUMONIA Train : 3875
# Data PNEUMONIA Validation : 8
# Data PNEUMONIA Test : 390
# Data TURBERCULOSIS Train : 650
# Data TURBERCULOSIS Validation : 12
# Data TURBERCULOSIS Test : 41

# %%
# TULIS KODE ANDA DISINI
from tensorflow.keras.preprocessing.image import ImageDataGenerator
batch_size=32

augmen_gen = ImageDataGenerator(rescale=1/255,rotation_range=30, width_shift_range=0.1,
                        height_shift_range=0.1, shear_range=0.2, 
                        zoom_range=0.8, horizontal_flip=True,
                        fill_mode="nearest")
#melakukan class mode= metode pemilihan clasifikasi, taret size= dimensi citra, batch size= banyak citra yg dimasukkan setiap step, shuffle= acak data tida sesusai alfabetik
train_aug = augmen_gen.flow_from_directory(
    '/tmp/chest-xray-pneumoniacovid19tuberculosis/train',
    class_mode = 'categorical',
    shuffle=True,
    target_size = (50,50),
    batch_size=batch_size,
    color_mode ='rgb'
)

test_aug = augmen_gen.flow_from_directory(
    '/tmp/chest-xray-pneumoniacovid19tuberculosis/test',
    class_mode = 'categorical',
    shuffle=False,
    target_size = (50,50),
    batch_size=batch_size,
    color_mode ='rgb',
)
# Out:
# Found 6326 images belonging to 4 classes.
# Found 771 images belonging to 4 classes.

# %%
train_covid19_images = glob(train+"/COVID19/*")
train_turberculosis_images = glob(train+"/TURBERCULOSIS/*")

plt.figure(figsize=(10, 8), dpi=80)
init_subplot = 230
for i in range(1, 7):
    plt.subplot(init_subplot + i)
    
    if i < 4:
        img = Image.open(np.random.choice(train_covid19_images)).resize((150, 150))
        plt.title("Foto COVID19")
    else:
        img = Image.open(np.random.choice(train_turberculosis_images)).resize((150, 150))
        plt.title("Foto TURBERCULOSIS")
    
    img = np.asarray(img)
    plt.axis('off')
    plt.imshow(img)

# %%
train_normal_images = glob(train+"/NORMAL/*")
train_pneumonia_images = glob(train+"/PNEUMONIA/*")

plt.figure(figsize=(10, 8), dpi=80)
init_subplot = 230

for j in range(1,7):
    plt.subplot(init_subplot + j)

    if j < 4:
        img = Image.open(np.random.choice(train_normal_images)).resize((150, 150))
        plt.title("Foto NORMAL")
    else:
        img = Image.open(np.random.choice(train_pneumonia_images)).resize((150, 150))
        plt.title("Foto PNEUMONIA")
    
    img = np.asarray(img)
    plt.axis('off')
    plt.imshow(img)

# %%
IMAGE_SIZE = [50, 50]

categories = ["COVID19", "NORMAL","PNEUMONIA","TURBERCULOSIS"]

# %%
# Menambahkan Layer untuk Preprocessing pada VGG
vgg = VGG16(input_shape = IMAGE_SIZE + [3], 
            weights = 'imagenet',
            include_top=False)


# Untuk perintah menolak men training data yang telah digunakan sebelumnya
for layer in vgg.layers:
  layer.trainable = False

# %%
x = Flatten()(vgg.output)
x = Dense(1000, activation='relu')(x)

# Lapisan Terakhir dengan aktivasi softmax untuk output biner 
prediction = Dense(len(categories), activation='softmax')(x)

# %%
# Membuat obbjek model 
model = Model(inputs=vgg.input, outputs=prediction)

# Melihat struktur model
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 50, 50, 3)]       0
#
#  block1_conv1 (Conv2D)       (None, 50, 50, 64)        1792
#
#  block1_conv2 (Conv2D)       (None, 50, 50, 64)        36928
#
#  block1_pool (MaxPooling2D)  (None, 25, 25, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 25, 25, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 25, 25, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 12, 12, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 12, 12, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 12, 12, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 12, 12, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 6, 6, 256)         0
#
#  block4_conv1 (Conv2D)       (None, 6, 6, 512)         1180160
#
#  block4_conv2 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block4_conv3 (Conv2D)       (None, 6, 6, 512)         2359808
#
#  block4_pool (MaxPooling2D)  (None, 3, 3, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 3, 3, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 3, 3, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 3, 3, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 1, 1, 512)         0
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 1000)              513000
#
#  dense_3 (Dense)             (None, 4)                 4004
#
# =================================================================
# Total params: 15,231,692
# Trainable params: 517,004
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# tell the model what cost and optimization method to use
from tensorflow.keras.optimizers import Adam
model.compile(
  loss='categorical_crossentropy',
  optimizer=Adam(lr=0.001),
  metrics=['accuracy']
)

# %%
# Mencocokan model
r = model.fit_generator(
  train_aug,
  validation_data=test_aug,
  epochs=100,
  steps_per_epoch=len(train_aug), 
  validation_steps=len(test_aug)
)
# Out:
# Epoch 1/100
# 198/198 [==============================] - 99s 493ms/step - loss: 0.7336 - accuracy: 0.7131 - val_loss: 0.7602 - val_accuracy: 0.6887
# Epoch 2/100
# 198/198 [==============================] - 95s 482ms/step - loss: 0.5876 - accuracy: 0.7686 - val_loss: 0.7576 - val_accuracy: 0.6965
# Epoch 3/100
# 198/198 [==============================] - 94s 474ms/step - loss: 0.5530 - accuracy: 0.7801 - val_loss: 0.7061 - val_accuracy: 0.7315
# Epoch 4/100
# 198/198 [==============================] - 97s 488ms/step - loss: 0.5445 - accuracy: 0.7869 - val_loss: 0.8129 - val_accuracy: 0.6706
# Epoch 5/100
# 198/198 [==============================] - 97s 491ms/step - loss: 0.5030 - accuracy: 0.7964 - val_loss: 0.6614 - val_accuracy: 0.7276
# Epoch 6/100
# 198/198 [==============================] - 96s 483ms/step - loss: 0.4986 - accuracy: 0.8048 - val_loss: 0.6636 - val_accuracy: 0.7315
# Epoch 7/100
# 198/198 [==============================] - 96s 483ms/step - loss: 0.5028 - accuracy: 0.8037 - val_loss: 0.6626 - val_accuracy: 0.7393
# Epoch 8/100
# 198/198 [==============================] - 95s 480ms/step - loss: 0.4831 - accuracy: 0.8149 - val_loss: 0.6901 - val_accuracy: 0.7354
# Epoch 9/100
# 198/198 [==============================] - 94s 476ms/step - loss: 0.4749 - accuracy: 0.8147 - val_loss: 0.7946 - val_accuracy: 0.6757
# Epoch 10/100
# 198/198 [==============================] - 97s 488ms/step - loss: 0.4701 - accuracy: 0.8144 - val_loss: 0.6517 - val_accuracy: 0.7354
# Epoch 11/100
# 198/198 [==============================] - 97s 488ms/step - loss: 0.4679 - accuracy: 0.8198 - val_loss: 0.7073 - val_accuracy: 0.7302
# Epoch 12/100
# 198/198 [==============================] - 96s 487ms/step - loss: 0.4559 - accuracy: 0.8187 - val_loss: 0.6756 - val_accuracy: 0.7289
# Epoch 13/100
# 198/198 [==============================] - 95s 478ms/step - loss: 0.4615 - accuracy: 0.8152 - val_loss: 0.6507 - val_accuracy: 0.7432
# Epoch 14/100
# 198/198 [==============================] - 95s 482ms/step - loss: 0.4491 - accuracy: 0.8237 - val_loss: 0.6518 - val_accuracy: 0.7471
# Epoch 15/100
# 198/198 [==============================] - 95s 478ms/step - loss: 0.4445 - accuracy: 0.8260 - val_loss: 0.6428 - val_accuracy: 0.7289
# Epoch 16/100
# 198/198 [==============================] - 94s 476ms/step - loss: 0.4333 - accuracy: 0.8323 - val_loss: 0.6464 - val_accuracy: 0.7471
# Epoch 17/100
# 198/198 [==============================] - 93s 473ms/step - loss: 0.4311 - accuracy: 0.8309 - val_loss: 0.8327 - val_accuracy: 0.6563
# Epoch 18/100
# 198/198 [==============================] - 94s 477ms/step - loss: 0.4424 - accuracy: 0.8230 - val_loss: 0.6259 - val_accuracy: 0.7497
# Epoch 19/100
# 198/198 [==============================] - 94s 475ms/step - loss: 0.4340 - accuracy: 0.8312 - val_loss: 0.7670 - val_accuracy: 0.6861
# Epoch 20/100
# 198/198 [==============================] - 94s 477ms/step - loss: 0.4203 - accuracy: 0.8361 - val_loss: 0.6069 - val_accuracy: 0.7626
# Epoch 21/100
# 198/198 [==============================] - 94s 476ms/step - loss: 0.4350 - accuracy: 0.8293 - val_loss: 0.5464 - val_accuracy: 0.7730
# Epoch 22/100
# 198/198 [==============================] - 97s 486ms/step - loss: 0.4229 - accuracy: 0.8343 - val_loss: 0.6075 - val_accuracy: 0.7445
# Epoch 23/100
# 198/198 [==============================] - 99s 502ms/step - loss: 0.4195 - accuracy: 0.8310 - val_loss: 0.6042 - val_accuracy: 0.7536
# Epoch 24/100
# 198/198 [==============================] - 98s 495ms/step - loss: 0.4348 - accuracy: 0.8329 - val_loss: 0.6355 - val_accuracy: 0.7575
# Epoch 25/100
# 198/198 [==============================] - 98s 496ms/step - loss: 0.4084 - accuracy: 0.8377 - val_loss: 0.6782 - val_accuracy: 0.7185
# Epoch 26/100
# 198/198 [==============================] - 99s 503ms/step - loss: 0.4055 - accuracy: 0.8407 - val_loss: 0.6842 - val_accuracy: 0.7458
# Epoch 27/100
# 198/198 [==============================] - 99s 500ms/step - loss: 0.4127 - accuracy: 0.8364 - val_loss: 0.5678 - val_accuracy: 0.7808
# Epoch 28/100
# 198/198 [==============================] - 97s 490ms/step - loss: 0.4036 - accuracy: 0.8386 - val_loss: 0.6652 - val_accuracy: 0.7315
# Epoch 29/100
# 198/198 [==============================] - 97s 489ms/step - loss: 0.3878 - accuracy: 0.8494 - val_loss: 0.7079 - val_accuracy: 0.7341
# Epoch 30/100
# 198/198 [==============================] - 96s 487ms/step - loss: 0.4066 - accuracy: 0.8411 - val_loss: 0.7012 - val_accuracy: 0.7211
# Epoch 31/100
# 198/198 [==============================] - 97s 492ms/step - loss: 0.4036 - accuracy: 0.8364 - val_loss: 0.6470 - val_accuracy: 0.7484
# Epoch 32/100
# 198/198 [==============================] - 98s 495ms/step - loss: 0.4034 - accuracy: 0.8411 - val_loss: 0.6839 - val_accuracy: 0.7315
# Epoch 33/100
# 198/198 [==============================] - 97s 490ms/step - loss: 0.4127 - accuracy: 0.8369 - val_loss: 0.6088 - val_accuracy: 0.7575
# Epoch 34/100
# 198/198 [==============================] - 98s 496ms/step - loss: 0.4026 - accuracy: 0.8405 - val_loss: 0.6841 - val_accuracy: 0.7367
# Epoch 35/100
# 198/198 [==============================] - 100s 505ms/step - loss: 0.3980 - accuracy: 0.8400 - val_loss: 0.7231 - val_accuracy: 0.7302
# Epoch 36/100
# 198/198 [==============================] - 97s 491ms/step - loss: 0.4029 - accuracy: 0.8446 - val_loss: 0.6890 - val_accuracy: 0.7393
# Epoch 37/100
# 198/198 [==============================] - 97s 491ms/step - loss: 0.3999 - accuracy: 0.8476 - val_loss: 0.6700 - val_accuracy: 0.7432
# Epoch 38/100
# 198/198 [==============================] - 100s 505ms/step - loss: 0.3852 - accuracy: 0.8473 - val_loss: 0.7854 - val_accuracy: 0.7056
# Epoch 39/100
# 198/198 [==============================] - 98s 492ms/step - loss: 0.3854 - accuracy: 0.8530 - val_loss: 0.6660 - val_accuracy: 0.7484
# Epoch 40/100
# 198/198 [==============================] - 100s 507ms/step - loss: 0.4026 - accuracy: 0.8468 - val_loss: 0.6199 - val_accuracy: 0.7575
# Epoch 41/100
# 198/198 [==============================] - 102s 514ms/step - loss: 0.3932 - accuracy: 0.8481 - val_loss: 0.6315 - val_accuracy: 0.7393
# Epoch 42/100
# 198/198 [==============================] - 101s 510ms/step - loss: 0.3843 - accuracy: 0.8489 - val_loss: 0.7664 - val_accuracy: 0.7173
# Epoch 43/100
# 198/198 [==============================] - 98s 494ms/step - loss: 0.3874 - accuracy: 0.8479 - val_loss: 0.7584 - val_accuracy: 0.7263
# Epoch 44/100
# 198/198 [==============================] - 97s 489ms/step - loss: 0.3864 - accuracy: 0.8522 - val_loss: 0.6408 - val_accuracy: 0.7575
# Epoch 45/100
# 198/198 [==============================] - 97s 491ms/step - loss: 0.3831 - accuracy: 0.8462 - val_loss: 0.6365 - val_accuracy: 0.7354
# Epoch 46/100
# 198/198 [==============================] - 96s 486ms/step - loss: 0.3816 - accuracy: 0.8516 - val_loss: 0.5397 - val_accuracy: 0.7886
# Epoch 47/100
# 198/198 [==============================] - 97s 491ms/step - loss: 0.3726 - accuracy: 0.8528 - val_loss: 0.6609 - val_accuracy: 0.7588
# Epoch 48/100
# 198/198 [==============================] - 97s 489ms/step - loss: 0.3811 - accuracy: 0.8519 - val_loss: 0.6282 - val_accuracy: 0.7639
# Epoch 49/100
# 198/198 [==============================] - 96s 487ms/step - loss: 0.3961 - accuracy: 0.8448 - val_loss: 0.6333 - val_accuracy: 0.7432
# Epoch 50/100
# 198/198 [==============================] - 96s 485ms/step - loss: 0.3822 - accuracy: 0.8482 - val_loss: 0.6244 - val_accuracy: 0.7601
# Epoch 51/100
# 198/198 [==============================] - 96s 486ms/step - loss: 0.3774 - accuracy: 0.8541 - val_loss: 0.6596 - val_accuracy: 0.7458
# Epoch 52/100
# 198/198 [==============================] - 96s 486ms/step - loss: 0.3785 - accuracy: 0.8538 - val_loss: 0.6266 - val_accuracy: 0.7769
# Epoch 53/100
# 198/198 [==============================] - 96s 486ms/step - loss: 0.3806 - accuracy: 0.8517 - val_loss: 0.6165 - val_accuracy: 0.7678
# Epoch 54/100
# 198/198 [==============================] - 96s 484ms/step - loss: 0.3755 - accuracy: 0.8536 - val_loss: 0.6495 - val_accuracy: 0.7419
# Epoch 55/100
# 198/198 [==============================] - 105s 532ms/step - loss: 0.3739 - accuracy: 0.8503 - val_loss: 0.6487 - val_accuracy: 0.7562
# Epoch 56/100
# 198/198 [==============================] - 96s 483ms/step - loss: 0.3815 - accuracy: 0.8509 - val_loss: 0.6690 - val_accuracy: 0.7484
# Epoch 57/100
# 198/198 [==============================] - 97s 492ms/step - loss: 0.3725 - accuracy: 0.8546 - val_loss: 0.6421 - val_accuracy: 0.7588
# Epoch 58/100
# 198/198 [==============================] - 100s 505ms/step - loss: 0.3752 - accuracy: 0.8533 - val_loss: 0.7205 - val_accuracy: 0.7198
# Epoch 59/100
# 198/198 [==============================] - 101s 510ms/step - loss: 0.3690 - accuracy: 0.8596 - val_loss: 0.6431 - val_accuracy: 0.7419
# Epoch 60/100
# 198/198 [==============================] - 101s 512ms/step - loss: 0.3742 - accuracy: 0.8577 - val_loss: 0.5666 - val_accuracy: 0.7769
# Epoch 61/100
# 198/198 [==============================] - 101s 511ms/step - loss: 0.3701 - accuracy: 0.8552 - val_loss: 0.5837 - val_accuracy: 0.7717
# Epoch 62/100
# 198/198 [==============================] - 104s 524ms/step - loss: 0.3718 - accuracy: 0.8524 - val_loss: 0.6435 - val_accuracy: 0.7575
# Epoch 63/100
# 198/198 [==============================] - 103s 520ms/step - loss: 0.3678 - accuracy: 0.8525 - val_loss: 0.5946 - val_accuracy: 0.7678
# Epoch 64/100
# 198/198 [==============================] - 104s 526ms/step - loss: 0.3759 - accuracy: 0.8569 - val_loss: 0.6256 - val_accuracy: 0.7588
# Epoch 65/100
# 198/198 [==============================] - 104s 523ms/step - loss: 0.3791 - accuracy: 0.8490 - val_loss: 0.6658 - val_accuracy: 0.7419
# Epoch 66/100
# 198/198 [==============================] - 104s 524ms/step - loss: 0.3650 - accuracy: 0.8574 - val_loss: 0.6346 - val_accuracy: 0.7601
# Epoch 67/100
# 198/198 [==============================] - 112s 565ms/step - loss: 0.3723 - accuracy: 0.8566 - val_loss: 0.6064 - val_accuracy: 0.7613
# Epoch 68/100
# 198/198 [==============================] - 101s 511ms/step - loss: 0.3598 - accuracy: 0.8614 - val_loss: 0.8476 - val_accuracy: 0.6965
# Epoch 69/100
# 198/198 [==============================] - 102s 515ms/step - loss: 0.3767 - accuracy: 0.8561 - val_loss: 0.6529 - val_accuracy: 0.7730
# Epoch 70/100
# 198/198 [==============================] - 102s 518ms/step - loss: 0.3613 - accuracy: 0.8614 - val_loss: 0.6728 - val_accuracy: 0.7458
# Epoch 71/100
# 198/198 [==============================] - 103s 518ms/step - loss: 0.3640 - accuracy: 0.8541 - val_loss: 0.6603 - val_accuracy: 0.7445
# Epoch 72/100
# 198/198 [==============================] - 102s 513ms/step - loss: 0.3585 - accuracy: 0.8592 - val_loss: 0.6246 - val_accuracy: 0.7562
# Epoch 73/100
# 198/198 [==============================] - 98s 494ms/step - loss: 0.3548 - accuracy: 0.8601 - val_loss: 0.6488 - val_accuracy: 0.7536
# Epoch 74/100
# 198/198 [==============================] - 95s 481ms/step - loss: 0.3623 - accuracy: 0.8574 - val_loss: 0.5420 - val_accuracy: 0.8042
# Epoch 75/100
# 198/198 [==============================] - 95s 482ms/step - loss: 0.3660 - accuracy: 0.8536 - val_loss: 0.6152 - val_accuracy: 0.7549
# Epoch 76/100
# 198/198 [==============================] - 95s 480ms/step - loss: 0.3637 - accuracy: 0.8539 - val_loss: 0.6141 - val_accuracy: 0.7652
# Epoch 77/100
# 198/198 [==============================] - 95s 480ms/step - loss: 0.3600 - accuracy: 0.8554 - val_loss: 0.5772 - val_accuracy: 0.7691
# Epoch 78/100
# 198/198 [==============================] - 94s 475ms/step - loss: 0.3554 - accuracy: 0.8622 - val_loss: 0.6467 - val_accuracy: 0.7497
# Epoch 79/100
# 198/198 [==============================] - 94s 475ms/step - loss: 0.3596 - accuracy: 0.8610 - val_loss: 0.5940 - val_accuracy: 0.7808
# Epoch 80/100
# 198/198 [==============================] - 93s 467ms/step - loss: 0.3572 - accuracy: 0.8599 - val_loss: 0.6307 - val_accuracy: 0.7639
# Epoch 81/100
# 198/198 [==============================] - 94s 474ms/step - loss: 0.3613 - accuracy: 0.8573 - val_loss: 0.6514 - val_accuracy: 0.7536
# Epoch 82/100
# 198/198 [==============================] - 94s 474ms/step - loss: 0.3694 - accuracy: 0.8571 - val_loss: 0.5589 - val_accuracy: 0.7652
# Epoch 83/100
# 198/198 [==============================] - 94s 476ms/step - loss: 0.3587 - accuracy: 0.8636 - val_loss: 0.5955 - val_accuracy: 0.7613
# Epoch 84/100
# 198/198 [==============================] - 93s 471ms/step - loss: 0.3655 - accuracy: 0.8577 - val_loss: 0.7464 - val_accuracy: 0.7302
# Epoch 85/100
# 198/198 [==============================] - 93s 471ms/step - loss: 0.3577 - accuracy: 0.8566 - val_loss: 0.7190 - val_accuracy: 0.7289
# Epoch 86/100
# 198/198 [==============================] - 95s 478ms/step - loss: 0.3550 - accuracy: 0.8606 - val_loss: 0.5777 - val_accuracy: 0.7704
# Epoch 87/100
# 198/198 [==============================] - 95s 482ms/step - loss: 0.3471 - accuracy: 0.8636 - val_loss: 0.6536 - val_accuracy: 0.7471
# Epoch 88/100
# 198/198 [==============================] - 96s 484ms/step - loss: 0.3506 - accuracy: 0.8601 - val_loss: 0.6829 - val_accuracy: 0.7367
# Epoch 89/100
# 198/198 [==============================] - 96s 483ms/step - loss: 0.3510 - accuracy: 0.8617 - val_loss: 0.6191 - val_accuracy: 0.7782
# Epoch 90/100
# 198/198 [==============================] - 98s 494ms/step - loss: 0.3531 - accuracy: 0.8622 - val_loss: 0.5956 - val_accuracy: 0.7626
# Epoch 91/100
# 198/198 [==============================] - 95s 478ms/step - loss: 0.3543 - accuracy: 0.8672 - val_loss: 0.6685 - val_accuracy: 0.7458
# Epoch 92/100
# 198/198 [==============================] - 94s 473ms/step - loss: 0.3487 - accuracy: 0.8634 - val_loss: 0.6966 - val_accuracy: 0.7549
# Epoch 93/100
# 198/198 [==============================] - 94s 473ms/step - loss: 0.3506 - accuracy: 0.8660 - val_loss: 0.5841 - val_accuracy: 0.7951
# Epoch 94/100
# 198/198 [==============================] - 96s 486ms/step - loss: 0.3502 - accuracy: 0.8677 - val_loss: 0.6467 - val_accuracy: 0.7613
# Epoch 95/100
# 198/198 [==============================] - 98s 493ms/step - loss: 0.3468 - accuracy: 0.8656 - val_loss: 0.6600 - val_accuracy: 0.7613
# Epoch 96/100
# 198/198 [==============================] - 103s 519ms/step - loss: 0.3489 - accuracy: 0.8636 - val_loss: 0.6272 - val_accuracy: 0.7704
# Epoch 97/100
# 198/198 [==============================] - 96s 486ms/step - loss: 0.3433 - accuracy: 0.8669 - val_loss: 0.6637 - val_accuracy: 0.7458
# Epoch 98/100
# 198/198 [==============================] - 97s 488ms/step - loss: 0.3436 - accuracy: 0.8639 - val_loss: 0.6345 - val_accuracy: 0.7497
# Epoch 99/100
# 198/198 [==============================] - 95s 482ms/step - loss: 0.3452 - accuracy: 0.8683 - val_loss: 0.6995 - val_accuracy: 0.7458
# Epoch 100/100
# 198/198 [==============================] - 96s 486ms/step - loss: 0.3414 - accuracy: 0.8618 - val_loss: 0.6051 - val_accuracy: 0.7665

# %%
fig, ax = plt.subplots(figsize=(20, 4), nrows=1, ncols=2)  

ax[0].plot(r.history['loss'], color='b', label="Training Loss")
ax[0].plot(r.history['val_loss'], color='r', label="Testing Loss",axes =ax[0])
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(r.history['accuracy'], color='b', label="Training Accuracy")
ax[1].plot(r.history['val_accuracy'], color='r',label="Testing Accuracy")
legend = ax[1].legend(loc='best', shadow=True)

# %%
from sklearn.metrics import classification_report
ypred = model.predict(test_aug)
prediction = np.argmax(ypred, axis=1)
print(classification_report(test_aug.classes, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.50      0.63       106
#            1       0.79      0.49      0.61       234
#            2       0.72      0.93      0.81       390
#            3       0.59      0.93      0.72        41
#
#     accuracy                           0.74       771
#    macro avg       0.74      0.71      0.69       771
# weighted avg       0.75      0.74      0.72       771

# %%
import tensorflow as tf
# (to generate a SavedModel) 

from google.colab import files

model.save('modelp1.h5')
files.download('modelp1.h5')
